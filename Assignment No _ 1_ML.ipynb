# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
db = pd.read_csv('House_Price_dataset.csv')
db
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %% [markdown]
# # **Perform the following operation on the given dataset.**

# %% [markdown]
# # **a) Load the Dataset**

# %%
db = pd.read_csv('House_Price_dataset.csv')
db
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %% [markdown]
# # **b) Find the shape of data**

# %%
db = db.shape
db
# Out:
# (545, 13)

# %% [markdown]
# # **c)  Find the summary of data**

# %%
db = pd.read_csv('House_Price_dataset.csv')
db
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %%
print(type(db))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
summary = db.describe(include='all')
summary
# Out:
#                price          area    bedrooms   bathrooms     stories  \
# count   5.450000e+02    545.000000  540.000000  540.000000  543.000000
# unique           NaN           NaN         NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN         NaN
# mean    4.766729e+06   5150.541284    2.961111    1.285185    1.804788
# std     1.870440e+06   2170.141023    0.738779    0.502464    0.869011
# min     1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%     3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%     4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%     5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max     1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#        mainroad guestroom basement hotwaterheating airconditioning  \
# ...

# %% [markdown]
# # **d) Find the data type of each column**

# %%
data_type = db.dtypes
data_type
# Out:
# price                 int64
# area                  int64
# bedrooms            float64
# bathrooms           float64
# stories             float64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking             float64
# prefarea             object
# furnishingstatus     object
# dtype: object

# %% [markdown]
# # **e) Find Missing Values**

# %%
missing_values = db.isnull().sum()
missing_values
# Out:
# price               0
# area                0
# bedrooms            5
# bathrooms           5
# stories             2
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             4
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# # **f) Finding out zero's**

# %%
zeros = (db==0).sum()
zeros
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking             297
# prefarea              0
# furnishingstatus      0
# dtype: int64

# %% [markdown]
# # **g) Find Mean**

# %%
print(db.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# Compute the mean of the 'Price' column
mean_price = db['price'].mean()
print("Mean price:", mean_price)
# Out:
# Mean price: 4766729.247706422

# %% [markdown]
# # **h) Repalce the missing values**

# %%
db["bathrooms"].fillna(1,inplace=True)
db[db.isna().any(axis=1)]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 14   9240000  7800       NaN        2.0      2.0      yes        no       no
# 88   6475000  7410       3.0        1.0      1.0      yes       yes      yes
# 98   6293000  6600       NaN        2.0      3.0      yes        no       no
# 108  6107500  3240       NaN        1.0      3.0      yes        no       no
# 183  5145000  7980       NaN        1.0      1.0      yes        no       no
# 239  4585000  4000       3.0        1.0      NaN      yes        no       no
# 241  4550000  3760       3.0        1.0      1.0      yes        no       no
# 248  4543000  4100       2.0        2.0      1.0      yes       yes      yes
# 251  4515000  3450       3.0        1.0      NaN      yes        no      yes
# 254  4480000  4510       NaN        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# # **i) Draw Pairplot**

# %%
sns.pairplot(db)
plt.show()

# %% [markdown]
# # **j) Create Subsets as per the Given Instructions**

# %% [markdown]
# # **1) All the Columns and first 100 rows**

# %%
db = db.iloc[:100,:]
db
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420       4.0        2.0      3.0      yes        no       no
# 1   12250000  8960       4.0        4.0      4.0      yes        no       no
# 2   12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3   12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4   11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 95   6300000  4100       3.0        2.0      3.0      yes        no       no
# 96   6300000  9000       3.0        1.0      1.0      yes        no      yes
# 97   6300000  6400       3.0        1.0      1.0      yes       yes      yes
# 98   6293000  6600       NaN        2.0      3.0      yes        no       no
# 99   6265000  6000       4.0        1.0      3.0      yes       yes      yes
#
# ...

# %% [markdown]
# # **2) All the rows and columns where status is furnished**

# %%
db = db[db['furnishingstatus'] == 'furnished']
db
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420       4.0        2.0      3.0      yes        no       no
# 1   12250000   8960       4.0        4.0      4.0      yes        no       no
# 3   12215000   7500       4.0        2.0      2.0      yes        no      yes
# 4   11410000   7420       4.0        1.0      2.0      yes       yes      yes
# 8    9870000   8100       4.0        1.0      2.0      yes       yes      yes
# 10   9800000  13200       3.0        1.0      2.0      yes        no      yes
# 13   9240000   3500       4.0        2.0      2.0      yes        no       no
# 17   8960000   8500       3.0        2.0      4.0      yes        no       no
# 18   8890000   4600       3.0        2.0      2.0      yes       yes       no
# 22   8645000   8050       3.0        1.0      1.0      yes       yes      yes
# 23   8645000   4560       3.0        2.0      2.0      yes       yes      yes
# ...

# %% [markdown]
# # **3) Only five important columns and rows**

# %%
db = db[['price','area','bathrooms','bedrooms','stories']]
db
# Out:
#        price   area  bathrooms  bedrooms  stories
# 0   13300000   7420        2.0       4.0      3.0
# 1   12250000   8960        4.0       4.0      4.0
# 3   12215000   7500        2.0       4.0      2.0
# 4   11410000   7420        1.0       4.0      2.0
# 8    9870000   8100        1.0       4.0      2.0
# 10   9800000  13200        1.0       3.0      2.0
# 13   9240000   3500        2.0       4.0      2.0
# 17   8960000   8500        2.0       3.0      4.0
# 18   8890000   4600        2.0       3.0      2.0
# 22   8645000   8050        1.0       3.0      1.0
# 23   8645000   4560        2.0       3.0      2.0
# 24   8575000   8800        1.0       3.0      2.0
# 25   8540000   6540        2.0       4.0      2.0
# 32   8295000   4880        2.0       4.0      2.0
# 34   8120000   6840        1.0       5.0      2.0
# 35   8080940   7000        2.0       3.0      4.0
# 36   8043000   7482        2.0       3.0      3.0
# 37   7980000   9000        2.0       4.0      4.0
# ...

# %% [markdown]
# # **4) All the samples where area >1000**

# %%
db = db[db['area'] > 1000]
db
# Out:
#        price   area  bathrooms  bedrooms  stories
# 0   13300000   7420        2.0       4.0      3.0
# 1   12250000   8960        4.0       4.0      4.0
# 3   12215000   7500        2.0       4.0      2.0
# 4   11410000   7420        1.0       4.0      2.0
# 8    9870000   8100        1.0       4.0      2.0
# 10   9800000  13200        1.0       3.0      2.0
# 13   9240000   3500        2.0       4.0      2.0
# 17   8960000   8500        2.0       3.0      4.0
# 18   8890000   4600        2.0       3.0      2.0
# 22   8645000   8050        1.0       3.0      1.0
# 23   8645000   4560        2.0       3.0      2.0
# 24   8575000   8800        1.0       3.0      2.0
# 25   8540000   6540        2.0       4.0      2.0
# 32   8295000   4880        2.0       4.0      2.0
# 34   8120000   6840        1.0       5.0      2.0
# 35   8080940   7000        2.0       3.0      4.0
# 36   8043000   7482        2.0       3.0      3.0
# 37   7980000   9000        2.0       4.0      4.0
# ...

# %% [markdown]
# # **5) Subset with rows 10 to 150 with no guestroom and no of bathrooms >=2**

# %%
db = pd.read_csv('House_Price_dataset.csv')
db
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %% [markdown]
# # **k) Divide database into training (75%) and testing (25%)**

# %%
from sklearn.model_selection import train_test_split

# %%
x=db['area']
y=db['price']

# %%
train, test = train_test_split(db, test_size=0.25, random_state=42)

# %%
print(f"Training set shape: {train.shape}")
print(f"Testing set shape: {test.shape}")
# Out:
# Training set shape: (408, 13)
# Testing set shape: (137, 13)
